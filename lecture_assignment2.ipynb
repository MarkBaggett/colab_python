# %% [markdown]
# # Assignment2
#
# It is time to begin your first programming assignment. You will be putting together concepts you have already learned into a functioning tool you can you. Your first assignment is "hash_search.py"
#
# First lets get the question and review the different components.

# %%
#Import and/or install the pywars client
# !git clone --branch version5 https://github.com/markbaggett/pyWars
# !pip install ./pyWars

#Mount the google drive in colab
from google.colab import drive
drive.mount('/content/drive')

# %%
#Set the following three variables and execute this cell
HOSTNAME = "Host Name Here"
USERNAME = "your login here"
PASSWORD = "your password here"

#This will create your pywars client object and store in the variable d
import pywars
d = pywars.Client(f"https://{HOSTNAME}:10000")
d.file_location="/content/drive/MyDrive"
d.login(USERNAME,PASSWORD)

# %%
d.question("assignment2")

# %% [markdown]
# Now lets look at the different components.

# %% [markdown]
# Now lets look at the different components.

# %% [markdown]
# Here are some concepts you will need to complete this assignment.
#
# The os module has some components you will need in this lab.

# %%
import os

os.path.exists("/drive/sample_data/README.md")

# %%
os.listdir("/drive/sample_data")

# %%
os.path.join()

# %% [markdown]
# Lets talk about calculating hashes

# %%
import hashlib

hashlib.md5(b"Hello World").hexdigest()

# %% [markdown]
# We have already talked about reading files. You will have to read them as bytes.

# %%
file_content = open("/content/sample_data/README.md","rb").read()
hashlib.md5(file_content).hexdigest()

# %% [markdown]
# Remember how to execute code within colab.  Proceed your command with an exclamation point

# %%
# !python3 /content/drive/MyDrive/assignment1/hash_search.py  ARG1 ARG2

# %% [markdown]
# Besure to test your program with all of the test that are outline in the README.
#
# When you are done submit your code with .solution().  It will give you errors and helpful messages

# %%
d.solution("/content/drive/MyDrive/assignment1/hash_search.py")
