# %% [markdown]
# # Python List Variables
#
# https://docs.python.org/3/library/stdtypes.html#text-sequence-type-str

# %%
#This cell changes the notebooks default behavior of only showing
#the last item in a cell and causes it to show all the values in a cell.

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# List are collections of other literal values. We use delimiters [] to identify them and comma separate the values.  For example
#
# `x = ['alice','bob','eve']`

# %%
#Here are ways that we can create lists

# Using square brackets
my_list = ["alice", "bob", "eve"]
print(my_list)

# Using the list() constructor
my_list = list("alice", "bob", "eve")
print(my_list)

# Using append() method
my_list = []
my_list.append("alice")
my_list.append("bob")
my_list.append("eve")
print(my_list)

# Using str.split()
my_str = "alice bob eve"
my_list = my_str.split()
print(my_list)

# %% [markdown]
# The `range()` function can generate numbers give an start, stop and step. It is intended to be used with a `for` loop so calling it does not return a list.  But if you pass it to list you can see the values it generates.

# %%
#Range saves memory by not building the list in memory
x = range(10)
print("range generated this", x)

#But it works well with for loops
for number in range(5):
    print("number is ", number)

# %%
#Just passing an integer generates numbers from 0 up to and not including that number
print(list(range(10)))

#You an provide a start and a stop (up to but not including)
print(list(range(5,20)))

#You can also provide a step (ie "count by")
print(list(range(5,100,25)))

#Using negatives works very similar to slicing
print(list(range(100,-50, -25 )))

# %% [markdown]
# We count the positions in the list starting at 0.
# The last used position in a list is len(the-list) -1

# %%
my_list = ["alice", "bob", "eve"]
#The item in position 0 is:
print("The first item is ",my_list[0])

#The number of items in the list is:
print("The length of the list is",len(my_list))

#The last item in the list is:
print("The last item in the list is",x[len(my_list)-1])

# %%
#We can now use positions to access and change values in the list!
print("The item in position 0 is", my_list[0])
print("The item in position -1 is",my_list[-1])

#We can also change values!
my_list[0] = "ALICE'S FRIEND"
print("Here is the updated list", x)

#You can not assign a value beyond the current end of the list! This is an error:
my_list[5] = "Add a new value"

#Instead you have to use a method to add values.

# %% [markdown]
# ## List Methods are different than String Methods!

# %% [markdown]
# NOTE: These are "mutable" data structures. They behave very differently than "immutable" data structures.
#
# With a string we UPDATE a variable like this:

# %%
#This is how we update mutable data structures
x = "hello world"
x = x.upper()
print("This is the updated x", x)

# %% [markdown]
# But this same syntax would completely ERASE my list!

# %%
#This same syntax erases the contents of variable x
x = ['alice','bob','eve']
x = x.append("charlie")
print("This is the updated x", x)  # x is None!!!

# %%
#The reason for this is because our list methods "return" nothing and update the variable
x = ['alice','bob','eve']
#Notice that the results of this is NONE. So we assigned x = None!!
print(x.append("charlie"))
#It did actually append the value.  Look at x now!
print(x)

# %% [markdown]
# ## List Methods

# %%
# Create a list with some initial values
my_list = [1, 2, 3, 4, 5]

# Using append() to add a new value to the end of the list
my_list.append(6)
print("After append(6): ", my_list)

# Using clear() to remove all the values from the list
my_list.clear()
print("After clear(): ", my_list)

# Create a new list with some values and use copy() to copy the list
new_list = [7, 8, 9]
copied_list = new_list.copy()
print("After copy(): ", copied_list)

# Using count() to count the occurrences of a value in the list
my_list = [1, 2, 2, 3, 3, 3]
count = my_list.count(2)
print("After count(2): ", count)

# Using extend() to add multiple values to the end of the list
my_list.extend([4, 5, 6])
print("After extend([4, 5, 6]): ", my_list)

# Using index() to find the position of a value in the list
index = my_list.index(3)
print("After index(3): ", index)

# Using insert() to insert a value at a specific position in the list
my_list.insert(0, 0)
print("After insert(0, 0): ", my_list)

# Using pop() to remove and return a value from a specific position in the list
popped_value = my_list.pop(2)
print("After pop(2): ", my_list, "popped value: ", popped_value)

# Using remove() to remove the first occurrence of a value from the list
my_list.remove(3)
print("After remove(3): ", my_list)

# Using reverse() to reverse the order of the values in the list
my_list.reverse()
print("After reverse(): ", my_list)

# Using sort() to sort the values in the list
my_list = [5, 2, 8, 1, 4]
my_list.sort()
print("After sort(): ", my_list)

# %%
# Using the + operator to concatenate two lists
a = [1, 2, 3]
b = [4, 5, 6]
c = a + b
print("Concatenated lists:", c)  # Output: [1, 2, 3, 4, 5, 6]

# Using the += operator to append elements to a list
d = [7, 8, 9]
d += [10, 11]
print("Updated list:", d)  # Output: [7, 8, 9, 10, 11]

# %%
# Using the <, >, <=, and >= operators to compare lists element-wise
list1 = [1, 2, 3]
list2 = [2, 3, 4]
# is 1 < 2 and 2 < 3 and 3 < 4 ?
print("list1 < list2:", list1 < list2)  # Output: True
print("list1 > list2:", list1 > list2)  # Output: False
print("list1 <= list2:", list1 <= list2)  # Output: True
print("list1 >= list2:", list1 >= list2)  # Output: False

#What what happens when we change list2[1] to 2

# Using the == and != operators to compare two lists for equality
list3 = [1, 2, 3]
list4 = [1, 2, 3]
list5 = [3, 2, 1]   # same members but a different order
print("list3 == list4:", list3 == list4)  # Output: True
print("list3 != list5:", list3 != list5)  # Output: True

#To see if members are the same we sort them and compare them
print("Same members?" sorted(list3) == sorted(list5))

# %% [markdown]
# ## List Slicing
#
# Python Slicing operations work on lists just like they do on strings.
#
# list_object[start:stop:step]

# %%
# Example 1: Extract the first three elements
names = ['alice', 'bob', 'eve', 'charlie', 'dave', 'frank']
first_three = names[:3]
print("Extracted the first three elements:", first_three)

# Example 2: Extract the last two elements
last_two = names[-2:]
print("Extracted the last two elements:", last_two)

# Example 3: Update the third element to 'emily'
names[2] = 'emily'
print("Updated the third element:", names)

# Example 4: Extract elements 2 through 4
elements_2_to_4 = names[1:4]
print("Extracted elements 2 through 4:", elements_2_to_4)

# Example 5: Update the last three elements to 'gina', 'harry', and 'isla'
names[-3:] = ['gina', 'harry', 'isla']
print("Updated the last three elements:", names)

# Example 6: Extract every other element starting from the second
every_other = names[1::2]
print("Extracted every other element starting from the second:", every_other)

# Example 7: Update elements 2 through 4 to 'fred'
names[1:4] = ['fred']
print("Updated elements 2 through 4 to 'fred':", names)

# Example 8: Extract every third element starting from the first
every_third = names[::3]
print("Extracted every third element starting from the first:", every_third)

# Example 9: Update the first element to 'abby'
names[0] = 'abby'
print("Updated the first element to 'abby':", names)

# Example 10: Extract elements 2 through 5 backwards
backwards = names[4:1:-1]
print("Extracted elements 2 through 5 backwards:", backwards)

# %% [markdown]
# Sorting Lists

# %%
# create a list of customer names
customers = ['Alice Smith', 'Bob Johnson', 'Eve Brown', 'Charlie Davis']

# sort the list alphabetically
sorted_customers = sorted(customers)
print("Sorted by customer name:", sorted_customers)

# sort the list by lastname using a key function
def get_lastname(name):
    # split the name into firstname and lastname
    parts = name.split()
    # return the lastname
    return parts[-1]

sorted_customers_by_lastname = sorted(customers, key=get_lastname)
print("Sorted by lastname:", sorted_customers_by_lastname)

# %% [markdown]
# ### iteration (for loops)
#
# List are FREQUENTLY used with for loops so that we can access each of the values in the list. Lets look at some examples.

# %%
#How can we add all of the numbers in a list?

add_these = [ 5, 6, 7, 8, 9 ]
result = 0
for each_number in add_these:
    result = result + each_number
print(result)

# %% [markdown]
# [watch this](https://pythontutor.com/visualize.html#code=add_these%20%3D%20%5B%205,%206,%207,%208,%209%20%5D%0Aresult%20%3D%200%0Afor%20each_number%20in%20add_these%3A%0A%20%20%20%20result%20%3D%20result%20%2B%20each_number%0Aprint%28result%29&cumulative=false&heapPrimitives=nevernest&mode=edit&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false)

# %%
#Create a new list based on values from some other list (filter and change values)
starting_list = ["bob", "alice", "eve", "charlie", "donna", "frank"]
new_list = []
for each_name in starting_list:
    if each_name in ['alice','bob','eve']:
        new_list.append( each_name.upper() )
print("Filtered and changed result", new_list)

# %% [markdown]
# [watch this](https://pythontutor.com/visualize.html#code=%23Create%20a%20new%20list%20based%20on%20values%20from%20some%20other%20list%20%28filter%20and%20change%20values%29%0Astarting_list%20%3D%20%5B%22bob%22,%20%22alice%22,%20%22eve%22,%20%22charlie%22,%20%22donna%22,%20%22frank%22%5D%0Anew_list%20%3D%20%5B%5D%0Afor%20each_name%20in%20starting_list%3A%0A%20%20%20%20if%20each_name%20in%20%5B'alice','bob','eve'%5D%3A%0A%20%20%20%20%20%20%20%20new_list.append%28%20each_name.upper%28%29%20%29%0Aprint%28%22Filtered%20and%20changed%20result%22,%20new_list%29&cumulative=false&heapPrimitives=nevernest&mode=edit&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false)

# %% [markdown]
# ### Function Arguments
#
# List are "mutable" data structures so the methods we use updates the contents of a variable. When you pass a list into a function, you are passing just a variable name that points to the list in memory. When you access that list in memory you are changing the list.  So they appear to act more like global variables. This, at first, seems inconsistent with the rule we gave you earlier.  Remember a variable is local if :
#
# - In the definition of the function (inside the parenthesis)
# - On the left side of an equal sign in the functions code block
#
# But upon closer inspection it is not. Consider this:

# %%
my_list = ['alice', 'bob']

def add_eve( input_list ):
    input_list.append("eve")

add_eve(my_list)
print("my_list now contains", my_list)

# %% [markdown]
# [watch this](https://pythontutor.com/visualize.html#code=my_list%20%3D%20%5B'alice',%20'bob'%5D%0A%0Adef%20add_eve%28%20input_list%20%29%3A%0A%20%20%20%20input_list.append%28%22eve%22%29%0A%0A%0Aadd_eve%28my_list%29%0Aprint%28%22my_list%20now%20contains%22,%20my_list%29&cumulative=false&heapPrimitives=nevernest&mode=edit&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false)
#
# Notice that we do still get a local variable named `input_list`. But since list are a "mutable" type it points to the save value in memory as the global variable `my_list`. If you want functions to generate new copies of lists with different values than it was passed you have to explicitly make a copy in the function.

# %%
my_list = ['alice', 'bob']

def add_eve( input_list ):
    new_list = input_list.copy()
    new_list.append("eve")
    return new_list

print("The add_eve() function returned", add_eve(my_list))
print("my_list now contains", my_list)

# %% [markdown]
# [watch this](https://pythontutor.com/visualize.html#code=my_list%20%3D%20%5B'alice',%20'bob'%5D%0A%0Adef%20add_eve%28%20input_list%20%29%3A%0A%20%20%20%20new_list%20%3D%20input_list.copy%28%29%0A%20%20%20%20new_list.append%28%22eve%22%29%0A%20%20%20%20return%20new_list%0A%0Aprint%28%22The%20add_eve%28%29%20function%20returned%22,%20add_eve%28my_list%29%29%0Aprint%28%22my_list%20now%20contains%22,%20my_list%29&cumulative=false&heapPrimitives=nevernest&mode=edit&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false)
