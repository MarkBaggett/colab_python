# %% [markdown]
# # Assignment3
#
# It is time to begin your first programming assignment. You will be putting together concepts you have already learned into a functioning tool you can you. Your first assignment is "analyze_log.py"
#
# First lets get the question and review the different components.

# %%
#Import and/or install the pywars client
# !git clone --branch version5 https://github.com/markbaggett/pyWars
# !pip install ./pyWars

#Mount the google drive in colab
from google.colab import drive
drive.mount('/content/drive')

# %%
#Set the following three variables and execute this cell
HOSTNAME = "Host Name Here"
USERNAME = "your login here"
PASSWORD = "your password here"

#This will create your pywars client object and store in the variable d
import pywars
d = pywars.Client(f"https://{HOSTNAME}:10000")
d.file_location="/content/drive/MyDrive"
d.login(USERNAME,PASSWORD)

# %%
d.question("assignment3)

# %% [markdown]
# Now lets look at the different components.

# %%
#Lets review .find and .index


"THIS IS A STRING".find("STR")

# %%
"THIS IS A STRING".index("STR")

# %%
#Check for the existence of a substring in a string
"STR" in "THIS IS A STRING"

# %%
#slice a string
"THIS IS A STRING"[6:9]

# %%
#Reading a file into a list

file_content = open("/content/drive/MyDrive/assignment3/sample_log.txt").readlines()

# %% [markdown]
# Count how many times you see a value in a list with a dictionary

# %%
classes = [ 'sec573','sec573','sec673','sec406','sec673']

counter_dict = {}

#counter_dict = { 'sec573': 0, 'sec673': 0, 'sec406': 0}

for each_class in classes:
    if each_class in counter_dict:
        counter_dict[each_class] += 1
    # If the class is not in the dictionary, add it and set the count to 1

# %% [markdown]
# Remember to test your code with all of the provided test cases given in the README.

# %%
# !python3 /content/drive/MyDrive/assignment3/analyze_log.py  /content/drive/MyDrive/assignment3/sample_log.txt 30

# %% [markdown]
# Besure to test your program with all of the test that are outline in the README.
#
# When you are done submit your code with .solution().  It will give you errors and helpful messages

# %%
d.solution("/content/drive/MyDrive/assignment1/hash_search.py")
